# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:255, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     254 try:
# --> 255     fd = _os.open(file, flags, 0o600)
#     256 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\tmp_7i4l7ep'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ultralytics import YOLO
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 __version__ = '8.0.56'
# ----> 5 from ultralytics.yolo.engine.model import YOLO
#       6 from ultralytics.yolo.utils.checks import check_yolo as checks
#       8 __all__ = '__version__', 'YOLO', 'checks'  # allow simpler import
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\engine\model.py:6
#       3 import sys
#       4 from pathlib import Path
# ----> 6 from ultralytics import yolo  # noqa
#       7 from ultralytics.nn.tasks import (ClassificationModel, DetectionModel, SegmentationModel, attempt_load_one_weight,
#       8                                   guess_model_task, nn, yaml_model_load)
#       9 from ultralytics.yolo.cfg import get_cfg
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from . import v8
#       5 __all__ = 'v8',  # tuple or list
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8 import classify, detect, segment
#       5 __all__ = 'classify', 'segment', 'detect'
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\classify\predict.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 import torch
# ----> 5 from ultralytics.yolo.engine.predictor import BasePredictor
#       6 from ultralytics.yolo.engine.results import Results
#       7 from ultralytics.yolo.utils import DEFAULT_CFG, ROOT
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\engine\predictor.py:36
#      32 from pathlib import Path
#      34 import cv2
# ---> 36 from ultralytics.nn.autobackend import AutoBackend
#      37 from ultralytics.yolo.cfg import get_cfg
#      38 from ultralytics.yolo.data import load_inference_source
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\nn\autobackend.py:17
#      14 import torch.nn as nn
#      15 from PIL import Image
# ---> 17 from ultralytics.yolo.utils import LINUX, LOGGER, ROOT, yaml_load
#      18 from ultralytics.yolo.utils.checks import check_requirements, check_suffix, check_version, check_yaml
#      19 from ultralytics.yolo.utils.downloads import attempt_download_asset, is_url
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:610
#     606 # Run below code on yolo/utils init ------------------------------------------------------------------------------------
#     607
#     608 # Check first-install steps
#     609 PREFIX = colorstr('Ultralytics: ')
# --> 610 SETTINGS = get_settings()
#     611 DATASETS_DIR = Path(SETTINGS['datasets_dir'])  # global datasets directory
#     612 ENVIRONMENT = 'Colab' if is_colab() else 'Kaggle' if is_kaggle() else 'Jupyter' if is_jupyter() else \
#     613     'Docker' if is_docker() else platform.system()
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:568, in get_settings(file, version)
#     566 git_dir = get_git_dir()
#     567 root = git_dir or Path()
# --> 568 datasets_root = (root.parent if git_dir and is_dir_writeable(root.parent) else root).resolve()
#     569 defaults = {
#     570     'datasets_dir': str(datasets_root / 'datasets'),  # default datasets directory.
#     571     'weights_dir': str(root / 'weights'),  # default weights directory.
#    (...)
#     574     'uuid': hashlib.sha256(str(uuid.getnode()).encode()).hexdigest(),  # anonymized uuid hash
#     575     'settings_version': version}  # Ultralytics settings version
#     577 with torch_distributed_zero_first(RANK):
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:325, in is_dir_writeable(dir_path)
#     315 """
#     316 Check if a directory is writeable.
#     317
#    (...)
#     322     bool: True if the directory is writeable, False otherwise.
#     323 """
#     324 try:
# --> 325     with tempfile.TemporaryFile(dir=dir_path):
#     326         pass
#     327     return True
#
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:545, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors)
#     542 if _os.name == 'nt' and delete:
#     543     flags |= _os.O_TEMPORARY
# --> 545 (fd, name) = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     546 try:
#     547     file = _io.open(fd, mode, buffering=buffering,
#     548                     newline=newline, encoding=encoding, errors=errors)
#
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:255, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     253 _sys.audit("tempfile.mkstemp", file)
#     254 try:
# --> 255     fd = _os.open(file, flags, 0o600)
#     256 except FileExistsError:
#     257     continue    # try again
#
# KeyboardInterrupt:

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Requirement already satisfied: ultralytics in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (8.0.56)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (1.24.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: psutil in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: thop>=0.1.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (2.28.2)
# Requirement already satisfied: sentry-sdk in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from ultralytics) (0.15.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.39.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from requests>=2.23.0->ultralytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: typing-extensions in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from torch>=1.7.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from torch>=1.7.0->ultralytics) (1.11.1)
# Requirement already satisfied: filelock in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from torch>=1.7.0->ultralytics) (3.10.4)
# Requirement already satisfied: networkx in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from torch>=1.7.0->ultralytics) (3.0)
# Requirement already satisfied: jinja2 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: colorama in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sardo\miniconda3\envs\traffic_laws\lib\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:255, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     254 try:
# --> 255     fd = _os.open(file, flags, 0o600)
#     256 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\tmpx1mnqki6'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 get_ipython().run_line_magic('pip', 'install ultralytics')
# ----> 2 import ultralytics
#       3 ultralytics.checks()
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 __version__ = '8.0.56'
# ----> 5 from ultralytics.yolo.engine.model import YOLO
#       6 from ultralytics.yolo.utils.checks import check_yolo as checks
#       8 __all__ = '__version__', 'YOLO', 'checks'  # allow simpler import
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\engine\model.py:6
#       3 import sys
#       4 from pathlib import Path
# ----> 6 from ultralytics import yolo  # noqa
#       7 from ultralytics.nn.tasks import (ClassificationModel, DetectionModel, SegmentationModel, attempt_load_one_weight,
#       8                                   guess_model_task, nn, yaml_model_load)
#       9 from ultralytics.yolo.cfg import get_cfg
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from . import v8
#       5 __all__ = 'v8',  # tuple or list
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8 import classify, detect, segment
#       5 __all__ = 'classify', 'segment', 'detect'
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\v8\classify\predict.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 import torch
# ----> 5 from ultralytics.yolo.engine.predictor import BasePredictor
#       6 from ultralytics.yolo.engine.results import Results
#       7 from ultralytics.yolo.utils import DEFAULT_CFG, ROOT
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\engine\predictor.py:36
#      32 from pathlib import Path
#      34 import cv2
# ---> 36 from ultralytics.nn.autobackend import AutoBackend
#      37 from ultralytics.yolo.cfg import get_cfg
#      38 from ultralytics.yolo.data import load_inference_source
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\nn\autobackend.py:17
#      14 import torch.nn as nn
#      15 from PIL import Image
# ---> 17 from ultralytics.yolo.utils import LINUX, LOGGER, ROOT, yaml_load
#      18 from ultralytics.yolo.utils.checks import check_requirements, check_suffix, check_version, check_yaml
#      19 from ultralytics.yolo.utils.downloads import attempt_download_asset, is_url
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:610
#     606 # Run below code on yolo/utils init ------------------------------------------------------------------------------------
#     607
#     608 # Check first-install steps
#     609 PREFIX = colorstr('Ultralytics: ')
# --> 610 SETTINGS = get_settings()
#     611 DATASETS_DIR = Path(SETTINGS['datasets_dir'])  # global datasets directory
#     612 ENVIRONMENT = 'Colab' if is_colab() else 'Kaggle' if is_kaggle() else 'Jupyter' if is_jupyter() else \
#     613     'Docker' if is_docker() else platform.system()
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:568, in get_settings(file, version)
#     566 git_dir = get_git_dir()
#     567 root = git_dir or Path()
# --> 568 datasets_root = (root.parent if git_dir and is_dir_writeable(root.parent) else root).resolve()
#     569 defaults = {
#     570     'datasets_dir': str(datasets_root / 'datasets'),  # default datasets directory.
#     571     'weights_dir': str(root / 'weights'),  # default weights directory.
#    (...)
#     574     'uuid': hashlib.sha256(str(uuid.getnode()).encode()).hexdigest(),  # anonymized uuid hash
#     575     'settings_version': version}  # Ultralytics settings version
#     577 with torch_distributed_zero_first(RANK):
#
# File ~\miniconda3\envs\traffic_laws\lib\site-packages\ultralytics\yolo\utils\__init__.py:325, in is_dir_writeable(dir_path)
#     315 """
#     316 Check if a directory is writeable.
#     317
#    (...)
#     322     bool: True if the directory is writeable, False otherwise.
#     323 """
#     324 try:
# --> 325     with tempfile.TemporaryFile(dir=dir_path):
#     326         pass
#     327     return True
#
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:545, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors)
#     542 if _os.name == 'nt' and delete:
#     543     flags |= _os.O_TEMPORARY
# --> 545 (fd, name) = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     546 try:
#     547     file = _io.open(fd, mode, buffering=buffering,
#     548                     newline=newline, encoding=encoding, errors=errors)
#
# File ~\miniconda3\envs\traffic_laws\lib\tempfile.py:255, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     253 _sys.audit("tempfile.mkstemp", file)
#     254 try:
# --> 255     fd = _os.open(file, flags, 0o600)
#     256 except FileExistsError:
#     257     continue    # try again
#
# KeyboardInterrupt:

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
